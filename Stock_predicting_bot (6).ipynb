# %%
# Imports
import pandas as pd
import numpy as np
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
# Read the 4 csv files into Pandas DataFrames
Nasdaq_2010_df = pd.read_csv(
   Path("NASDAQ100_LIST_2010.csv"))

Nasdaq_2011_df = pd.read_csv(
   Path("NASDAQ100_LIST_2011.csv"))

Nasdaq_2012_df = pd.read_csv(
   Path("NASDAQ100_LIST_2012.csv"))

Ten_x_df = pd.read_csv(
   Path("NASDAQ100_y_Values.csv"))

# Review the DataFrames
Nasdaq_2010_df
# Out:
#        2010            P/E Sales Surprise Pct           P/B             D/E  \
# 0    TiCKER            NaN                NaN           NaN             NaN
# 1      ATVI  18.5669994354     -39.1660003662  1.4704999924               0
# 2      ADBE  19.6049995422       2.0050001144   3.015599966    29.151599884
# 3       ADP  19.3640003204       2.9700000286  3.9521000385    0.6076999903
# 4      AKAM  46.5839996338       0.5879999995  3.9396998882               0
# ..      ...            ...                ...           ...             ...
# 104     WFM     #LinkError         #LinkError    #LinkError      #LinkError
# 105    XLNX     #LinkError         #LinkError    #LinkError      #LinkError
# 106      VZ  15.9729995728      -0.2370000035  1.1636999846   60.7442016602
# 107    NVDA  24.0620002747       0.0189999994  3.0504000187               0
# 108     AMD  16.3600006104       0.8389999866   5.505300045  216.3869934082
#
# ...

# %%
# Review the DataFrames
Nasdaq_2011_df
# Out:
#        2011            P/E Sales Surprise Pct           P/B             D/E  \
# 0    TiCKER            NaN                NaN           NaN             NaN
# 1      ATVI             14     -35.9350013733  1.3436000347               0
# 2      ADBE  15.7060003281       6.1799998283  2.3996999264   26.0256996155
# 3       ADP  20.6149997711       0.2300000042   4.269299984     0.412499994
# 4      AKAM  27.5900001526       3.9719998837  2.6861999035               0
# ..      ...            ...                ...           ...             ...
# 104     WFM     #LinkError         #LinkError    #LinkError      #LinkError
# 105    XLNX     #LinkError         #LinkError    #LinkError      #LinkError
# 106      VZ  18.5739994049       0.0340000018  1.3221999407   64.1988983154
# 107    NVDA  13.8599996567       0.5310000181  2.1059000492               0
# 108     AMD  10.5880002975      -1.7000000477  2.3668999672  126.7923965454
#
# ...

# %%
# Review the DataFrames
Nasdaq_2012_df
# Out:
#        2012            P/E Sales Surprise Pct           P/B            D/E  \
# 0    TiCKER            NaN                NaN           NaN            NaN
# 1      ATVI   9.7431001663     -27.4440002441  1.0441999435              0
# 2      ADBE  20.4780006409        4.611000061  2.7987000942  22.4591007233
# 3       ADP  20.4050006866              0.875  4.3215999603   0.2470999956
# 4      AKAM  31.7129993439      -0.9470000267  3.0950000286              0
# ..      ...            ...                ...           ...            ...
# 104     WFM     #LinkError         #LinkError    #LinkError     #LinkError
# 105    XLNX     #LinkError         #LinkError    #LinkError     #LinkError
# 106      VZ  19.2310009003       1.1139999628  1.4437999725  60.7799987793
# 107    NVDA   14.595000267       0.9940000176  1.6081000566              0
# 108     AMD  14.1180000305       0.6359999776  3.1760001183  379.553894043
#
# ...

# %%
# Review the DataFrames
Ten_x_df
# Out:
#        2012     Price 2012 price max    y
# 0    TiCKER            NaN       NaN  NaN
# 1      ATVI  10.6199998856        81  0.0
# 2      ADBE  37.6800003052       534  1.0
# 3       ADP  56.9300003052     269.9  0.0
# 4      AKAM  40.9099998474    120.51  1.0
# ..      ...            ...       ...  ...
# 103     WDC  42.4900016785     34.79  0.0
# 104     WFM  45.5800018311       NaN  0.0
# 105    XLNX   35.861000061       NaN  0.0
# 106      VZ  43.2700004578     61.53  0.0
# 107     AMD   2.4000000954    154.81  1.0
#
# [108 rows x 4 columns]

# %%
Nasdaq_2010_df = Nasdaq_2010_df.drop(columns=['Price 2020'])
Nasdaq_2010_df.columns = ['TICKER','2010 P/E', '2010 Sales Surprise', '2010 P/B', '2010 D/E', '2010 ROE','2010 FCF','2010 PEG','2010 Market cap','2010 EBITDA','2010 beta','2010 Price']
Nasdaq_2010_df = Nasdaq_2010_df.iloc[1: , :]

# Review the DataFrame
Nasdaq_2010_df
# Out:
#     TICKER       2010 P/E 2010 Sales Surprise      2010 P/B        2010 D/E  \
# 1     ATVI  18.5669994354      -39.1660003662  1.4704999924               0
# 2     ADBE  19.6049995422        2.0050001144   3.015599966    29.151599884
# 3      ADP  19.3640003204        2.9700000286  3.9521000385    0.6076999903
# 4     AKAM  46.5839996338        0.5879999995  3.9396998882               0
# 5      AZN   7.8288002014        3.4700000286  2.7801001072    38.859500885
# ..     ...            ...                 ...           ...             ...
# 104    WFM     #LinkError          #LinkError    #LinkError      #LinkError
# 105   XLNX     #LinkError          #LinkError    #LinkError      #LinkError
# 106     VZ  15.9729995728       -0.2370000035  1.1636999846   60.7442016602
# 107   NVDA  24.0620002747        0.0189999994  3.0504000187               0
# 108    AMD  16.3600006104        0.8389999866   5.505300045  216.3869934082
#
# ...

# %%
Nasdaq_2011_df = Nasdaq_2011_df.drop(columns=['Price 2021'])
Nasdaq_2011_df.columns = ['TICKER','2011 P/E', '2011 Sales Surprise', '2011 P/B', '2011 D/E', '2011 ROE','2011 FCF','2011 PEG','2011 Market cap','2011 EBITDA','2011 beta','2011 Price']
Nasdaq_2011_df = Nasdaq_2011_df.iloc[1: , :]

# Review the DataFrame
Nasdaq_2011_df
# Out:
#     TICKER       2011 P/E 2011 Sales Surprise      2011 P/B        2011 D/E  \
# 1     ATVI             14      -35.9350013733  1.3436000347               0
# 2     ADBE  15.7060003281        6.1799998283  2.3996999264   26.0256996155
# 3      ADP  20.6149997711        0.2300000042   4.269299984     0.412499994
# 4     AKAM  27.5900001526        3.9719998837  2.6861999035               0
# 5      AZN   6.6989998817        0.6660000086  2.5494000912   31.2707996368
# ..     ...            ...                 ...           ...             ...
# 104    WFM     #LinkError          #LinkError    #LinkError      #LinkError
# 105   XLNX     #LinkError          #LinkError    #LinkError      #LinkError
# 106     VZ  18.5739994049        0.0340000018  1.3221999407   64.1988983154
# 107   NVDA  13.8599996567        0.5310000181  2.1059000492               0
# 108    AMD  10.5880002975       -1.7000000477  2.3668999672  126.7923965454
#
# ...

# %%
Nasdaq_2012_df = Nasdaq_2012_df.drop(columns=['Price 2022'])
Nasdaq_2012_df.columns = ['TICKER','2012 P/E', '2012 Sales Surprise', '2012 P/B', '2012 D/E', '2012 ROE','2012 FCF','2012 PEG','2012 Market cap','2012 EBITDA','2012 beta','2012 Price']
Nasdaq_2012_df = Nasdaq_2012_df.iloc[1: , :]

# Review the DataFrame
Nasdaq_2012_df
# Out:
#     TICKER       2012 P/E 2012 Sales Surprise      2012 P/B       2012 D/E  \
# 1     ATVI   9.7431001663      -27.4440002441  1.0441999435              0
# 2     ADBE  20.4780006409         4.611000061  2.7987000942  22.4591007233
# 3      ADP  20.4050006866               0.875  4.3215999603   0.2470999956
# 4     AKAM  31.7129993439       -0.9470000267  3.0950000286              0
# 5      AZN   7.1947999001        1.3500000238  2.4616000652  43.0551986694
# ..     ...            ...                 ...           ...            ...
# 104    WFM     #LinkError          #LinkError    #LinkError     #LinkError
# 105   XLNX     #LinkError          #LinkError    #LinkError     #LinkError
# 106     VZ  19.2310009003        1.1139999628  1.4437999725  60.7799987793
# 107   NVDA   14.595000267        0.9940000176  1.6081000566              0
# 108    AMD  14.1180000305        0.6359999776  3.1760001183  379.553894043
#
# ...

# %%
Ten_x_df = Ten_x_df.iloc[1: , :]
Ten_x_df = Ten_x_df.drop(columns=['Price 2012','price max'])
Ten_x_df.columns = ['TICKER', 'Y']
Ten_x_df = Ten_x_df.set_index('TICKER')

# Review the DataFrame
Ten_x_df
# Out:
#           Y
# TICKER
# ATVI    0.0
# ADBE    1.0
# ADP     0.0
# AKAM    1.0
# AZN     0.0
# ...     ...
# WDC     0.0
# WFM     0.0
# XLNX    0.0
# VZ      0.0
# AMD     1.0
#
# [107 rows x 1 columns]

# %%
# Merge 4 Dataframes
Nasdaq_df = pd.merge(pd.merge(pd.merge(Nasdaq_2010_df,Nasdaq_2011_df,on='TICKER'),Nasdaq_2012_df,on='TICKER'),Ten_x_df,on='TICKER')

# Set index
#Nasdaq_df = Nasdaq_df.set_index('TICKER')

# Drop dupes
Nasdaq_df = Nasdaq_df.drop_duplicates()

# Change #LinkErrors to NAs
Nasdaq_df = Nasdaq_df.replace('#LinkError', np.nan)

# Drop NAs
Nasdaq_df = Nasdaq_df.dropna()

# Review the DataFrame
#type(Nasdaq_df)

#print(Nasdaq_df.dtypes)

# %%
#Nasdaq_df.to_csv('Nasdaq_df.csv')

# %%
# Define the target set y
y = Nasdaq_df['Y']

# Display y
y
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      1.0
# 6      0.0
#       ...
# 101    0.0
# 105    0.0
# 109    0.0
# 112    0.0
# 113    1.0
# Name: Y, Length: 63, dtype: float64

# %%
# Define features X
X = Nasdaq_df.drop(columns=['TICKER','Y'])

# Review the features DataFrame
X = X.astype('float')
print(X.dtypes)
X
# Out:
# 2010 P/E               float64
# 2010 Sales Surprise    float64
# 2010 P/B               float64
# 2010 D/E               float64
# 2010 ROE               float64
# 2010 FCF               float64
# 2010 PEG               float64
# 2010 Market cap        float64
# 2010 EBITDA            float64
# 2010 beta              float64
# 2010 Price             float64
# 2011 P/E               float64
# 2011 Sales Surprise    float64
# 2011 P/B               float64
# 2011 D/E               float64
# 2011 ROE               float64
# 2011 FCF               float64
# 2011 PEG               float64
# 2011 Market cap        float64
# 2011 EBITDA            float64
# 2011 beta              float64
# 2011 Price             float64
# 2012 P/E               float64
# 2012 Sales Surprise    float64
# 2012 P/B               float64
# 2012 D/E               float64
# 2012 ROE               float64
# 2012 FCF               float64
# 2012 PEG               float64
# 2012 Market cap        float64
# ...

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 3.37885347e+00, -7.61180197e-02, -6.13030963e-01,
#         -5.05590006e-02, -1.35372352e+00, -6.72912457e-01,
#          8.42486577e-01, -5.82698711e-01, -5.85779998e-01,
#          9.90401589e-01,  7.14931359e-01,  2.30748392e+00,
#         -8.03002256e-02, -6.82577441e-01,  8.21916426e-01,
#         -1.41201395e+00, -4.99756134e-01,  2.09518884e-01,
#         -5.30280610e-01, -4.75215542e-01,  6.96885431e-01,
#          8.23700450e-01,  3.56245994e-01,  2.03757867e-01,
#          1.06722587e-01,  4.98372199e-01, -1.43348504e+00,
#         -4.67295468e-01,  2.62486192e-01, -4.47430993e-01,
#         -4.29226191e-01,  7.35151443e-01,  1.70717053e+00],
#        [-8.55641674e-01,  4.62107627e-01,  3.86632229e-02,
#         -1.70329625e-01,  1.25835800e+00,  5.75025929e+00,
#         -9.41754516e-01,  3.64308848e+00,  4.86301744e+00,
#         -1.03426429e-01, -2.34503138e-01, -6.23574788e-01,
#         -1.86273000e-01, -2.92746076e-01, -2.74660911e-01,
# ...

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])

# Review the number of features
number_input_features
# Out:
# 33

# %%
# Define the number of neurons in the output layer
number_output_neurons = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 99# (number_input_features + 1) // 2 

# Review the number hidden nodes in the first layer
hidden_nodes_layer1
# Out:
# 99

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = (hidden_nodes_layer1 + 1) // 2

# Review the number hidden nodes in the second layer
hidden_nodes_layer2
# Out:
# 50

# %%
# Create the Sequential model instance
nn = Sequential()

# %%
# Add the first hidden layer
nn.add(Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# %%
# Add the second hidden layer
nn.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# %%
# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 99)                3366
#
#  dense_1 (Dense)             (None, 50)                5000
#
#  dense_2 (Dense)             (None, 1)                 51
#
# ...
# Total params: 8,417
# Trainable params: 8,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 9ms/step - loss: 261.3848 - accuracy: 0.5957
# Epoch 2/50
# 2/2 [==============================] - 0s 5ms/step - loss: 411.4996 - accuracy: 0.8298
# Epoch 3/50
# 2/2 [==============================] - 0s 9ms/step - loss: 561.3106 - accuracy: 0.8298
# Epoch 4/50
# 2/2 [==============================] - 0s 11ms/step - loss: 544.5273 - accuracy: 0.8298
# Epoch 5/50
# 2/2 [==============================] - 0s 11ms/step - loss: 457.8791 - accuracy: 0.8298
# Epoch 6/50
# 2/2 [==============================] - 0s 7ms/step - loss: 339.7641 - accuracy: 0.8298
# Epoch 7/50
# 2/2 [==============================] - 0s 7ms/step - loss: 190.7952 - accuracy: 0.8511
# Epoch 8/50
# 2/2 [==============================] - 0s 10ms/step - loss: 81.2645 - accuracy: 0.7447
# Epoch 9/50
# 2/2 [==============================] - 0s 8ms/step - loss: 351.6441 - accuracy: 0.5106
# Epoch 10/50
# ...

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1/1 - 0s - loss: 0.9346 - accuracy: 0.0625 - 303ms/epoch - 303ms/step
# Loss: 0.9346107244491577, Accuracy: 0.0625

# %%
from sklearn import svm
from sklearn.metrics import classification_report

# %%
model=svm.SVC()
model=model.fit(X_train, y_train)


predictions=model.predict(X_test)

# %%
testing_report=classification_report(y_test,predictions)

print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      1.00      0.90        13
#          1.0       0.00      0.00      0.00         3
#
#     accuracy                           0.81        16
#    macro avg       0.41      0.50      0.45        16
# weighted avg       0.66      0.81      0.73        16
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
